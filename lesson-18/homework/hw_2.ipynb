# %% [markdown]
# Homework 2

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\admin\Desktop\hw\homeworks\lesson-18\task\tackoverflow_qa.csv')
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0   332289  2008-12-01 21:24:44   3184    5962784
# 1  2051744  2010-01-12 19:31:47    420     587728
# 2  2225995  2010-02-09 00:51:38     51      59922
# 3  5486226  2011-03-30 12:26:50      7       6393
# 4  5515021  2011-04-01 14:50:44     10      13744
#
#                                                title  answercount  \
# 0  How do I change the size of figures drawn with...           14
# 1                      How to invert the x or y axis           10
# 2               How can I create stacked line graph?            4
# 3                           Rolling median in python            5
# 4       Compute a compounded return series in Python            3
#
#    commentcount  favoritecount       quest_name  quest_rep         ans_name  \
# 0             1            0.0        tatwright    37837.0              NaN
# 1             3            0.0          DarkAnt     4211.0          Demitri
# ...

# %%
#1
df1 = df['creationdate']<('2014-01-01')
df[df1].head()
# Out:
#         id         creationdate  score  viewcount  \
# 0   332289  2008-12-01 21:24:44   3184    5962784
# 1  2051744  2010-01-12 19:31:47    420     587728
# 2  2225995  2010-02-09 00:51:38     51      59922
# 3  5486226  2011-03-30 12:26:50      7       6393
# 4  5515021  2011-04-01 14:50:44     10      13744
#
#                                                title  answercount  \
# 0  How do I change the size of figures drawn with...           14
# 1                      How to invert the x or y axis           10
# 2               How can I create stacked line graph?            4
# 3                           Rolling median in python            5
# 4       Compute a compounded return series in Python            3
#
#    commentcount  favoritecount       quest_name  quest_rep         ans_name  \
# 0             1            0.0        tatwright    37837.0              NaN
# 1             3            0.0          DarkAnt     4211.0          Demitri
# ...

# %%
#2
df2 = df['score']>50
df[df2].head()
# Out:
#          id         creationdate  score  viewcount  \
# 0    332289  2008-12-01 21:24:44   3184    5962784
# 1   2051744  2010-01-12 19:31:47    420     587728
# 2   2225995  2010-02-09 00:51:38     51      59922
# 7   6541123  2011-06-30 21:09:11    550     832218
# 12  7837722  2011-10-20 14:46:14    401     658113
#
#                                                 title  answercount  \
# 0   How do I change the size of figures drawn with...           14
# 1                       How to invert the x or y axis           10
# 2                How can I create stacked line graph?            4
# 7     Improve subplot size/spacing with many subplots            9
# 12  What is the most efficient way to loop through...           13
#
#     commentcount  favoritecount       quest_name  quest_rep       ans_name  \
# 0              1            0.0        tatwright    37837.0            NaN
# 1              3            0.0          DarkAnt     4211.0        Demitri
# ...

# %%
#3
df3 = (df['score']>50) & (df['score']<100)
df[df3].head()
# Out:
#           id         creationdate  score  viewcount  \
# 2    2225995  2010-02-09 00:51:38     51      59922
# 42   9787853  2012-03-20 13:36:09     80      62070
# 65  10065051  2012-04-08 18:01:13     98     126795
# 86  10457584  2012-05-05 00:00:12     87     137928
# 98  10591000  2012-05-14 21:01:58     80     130343
#
#                                                 title  answercount  \
# 2                How can I create stacked line graph?            4
# 42             join or merge with overwrite in pandas            4
# 65             python-pandas and databases like mysql           14
# 86  Redefining the Index in a Pandas DataFrame object            3
# 98          Specifying data type in Pandas csv reader            2
#
#     commentcount  favoritecount       quest_name  quest_rep      ans_name  \
# 2              0            0.0  David Underhill    15936.0          doug
# 42             0            0.0          saroele     9601.0  Wes McKinney
# ...

# %%
#4
df4 = df['ans_name'] == 'Scott Boston'
df[df4]
# Out:
#             id         creationdate  score  viewcount  \
# 5392  24290297  2014-06-18 16:06:35     90      95248
#
#                                                   title  answercount  \
# 5392  Pandas dataframe with multiindex column - merg...            6
#
#       commentcount  favoritecount quest_name  quest_rep      ans_name  \
# 5392             1            0.0    Zhubarb    11581.0  Scott Boston
#
#        ans_rep
# 5392  149017.0

# %%
#5
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0   332289  2008-12-01 21:24:44   3184    5962784
# 1  2051744  2010-01-12 19:31:47    420     587728
# 2  2225995  2010-02-09 00:51:38     51      59922
# 3  5486226  2011-03-30 12:26:50      7       6393
# 4  5515021  2011-04-01 14:50:44     10      13744
#
#                                                title  answercount  \
# 0  How do I change the size of figures drawn with...           14
# 1                      How to invert the x or y axis           10
# 2               How can I create stacked line graph?            4
# 3                           Rolling median in python            5
# 4       Compute a compounded return series in Python            3
#
#    commentcount  favoritecount       quest_name  quest_rep         ans_name  \
# 0             1            0.0        tatwright    37837.0              NaN
# 1             3            0.0          DarkAnt     4211.0          Demitri
# ...

# %%
#6
df6 = ((df['creationdate'] > '2014-03-01') &
      (df['creationdate'] < '2014-10-31') &
      (df['score'] < 5) &
      (df['ans_name'] == 'unutbu'))
df[df6].head()
# Out:
#             id         creationdate  score  viewcount  \
# 4743  22108562  2014-03-01 00:46:28      1       1499
# 4751  22183447  2014-03-04 21:28:48      4       4500
# 4773  23932479  2014-05-29 11:40:58      1       1102
# 4784  25514241  2014-08-26 19:59:59      1        140
# 4880  22836892  2014-04-03 11:54:41      3       3328
#
#                                                   title  answercount  \
# 4743  Python -- Pandas : How to apply aggfunc to dat...            2
# 4751  How to pass more than one parameter to map fun...            1
# 4773  Python Numpy arange bins should be shown in as...            1
# 4784  Pandas: set the value of a column in a row to ...            1
# 4880      in python pandas, how to save a 'grid chart'?            1
#
#       commentcount  favoritecount   quest_name  quest_rep ans_name   ans_rep
# 4743             3            NaN  user3367015       53.0   unutbu  852025.0
# ...

# %%
#df7
df7 = (((df['score']>5) & 
        (df['score']<10)) | 
        (df['viewcount']>10000))
df[df7]
# Out:
#             id         creationdate  score  viewcount  \
# 0       332289  2008-12-01 21:24:44   3184    5962784
# 1      2051744  2010-01-12 19:31:47    420     587728
# 2      2225995  2010-02-09 00:51:38     51      59922
# 3      5486226  2011-03-30 12:26:50      7       6393
# 4      5515021  2011-04-01 14:50:44     10      13744
# ...        ...                  ...    ...        ...
# 9401  26921943  2014-11-14 02:27:53     28      59154
# 9404  27524169  2014-12-17 11:05:47      5      15767
# 9406  27020707  2014-11-19 15:32:13      6      20062
# 9414  27673231  2014-12-28 02:22:27    360     348337
# 9427  27718650  2014-12-31 08:57:47     15      17818
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
# df 8
df8 = df['ans_name'] != "Scott Boston"
df[df8]
# Out:
#             id         creationdate  score  viewcount  \
# 0       332289  2008-12-01 21:24:44   3184    5962784
# 1      2051744  2010-01-12 19:31:47    420     587728
# 2      2225995  2010-02-09 00:51:38     51      59922
# 3      5486226  2011-03-30 12:26:50      7       6393
# 4      5515021  2011-04-01 14:50:44     10      13744
# ...        ...                  ...    ...        ...
# 9458  27627397  2014-12-23 20:15:38      0        611
# 9459  27693117  2014-12-29 17:13:03      0       2893
# 9460  27673337  2014-12-28 02:53:36      3       2125
# 9461  27712500  2014-12-30 21:01:45      2        266
# 9462  27712482  2014-12-30 20:59:58      0        183
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...
